# %%
s=100
print(s)
# Out:
# 100

# %% [markdown]
# とりあえず、下記、リンク先のコードをコピペして実行してみる。
#
# http://mashiroyuya.hatenablog.com/entry/2016/06/02/Jupyter%E3%81%A7Python%E3%82%92%E4%BD%BF%E3%81%A3%E3%81%A6%E3%81%84%E3%81%93%E3%81%86_%E5%88%9D%E5%BF%83%E8%80%85%E3%81%AEpython

# %%
import numpy 
# %matplotlib inline
from matplotlib import pyplot
x = numpy.arange(0,10,0.1)
y = numpy.cos(x)
pyplot.plot(x,y)

# %% [markdown]
# ちゃんと動いているようだ。

# %%
# -*- coding: utf-8 -*-
from google import search

def google_search(query, limit=10):
    for url in search(query, lang="jp", num=limit):
        print(url)


#def main():
#    google_search("qiita")
google_search("qiita")
# Out:
# https://qiita.com/
# https://qiita.com/login?redirect_to=%2Forganizations%2Fidcf
# https://qiita.com/about
# https://qiita.com/takeharu/items/bb154a4bc198fb102ff3
# https://qiita.com/Qiita
# https://twitter.com/qiita
# https://ja.wikipedia.org/wiki/Qiita
# https://ferret-plus.com/1856
# https://www.sbbit.jp/article/cont1/32877
# http://techblog.kayac.com/qiita-iine-challenge
# http://jp.techcrunch.com/2017/12/22/ateam-increments/
# http://hrnabi.com/2017/09/07/15034/
# https://html5experts.jp/miyuki-baba/20328/
# https://increments.co.jp/products/qiita-team/
# http://www.itmedia.co.jp/business/articles/1712/22/news108.html
# http://mizchi.hatenablog.com/entry/2017/03/01/153816
# http://thebridge.jp/2017/12/qiita-acquired-by-ateam
# https://itunes.apple.com/jp/app/miniq-for-qiita-qiita-team/id969915776?mt=8
# https://suzuri.jp/qiita
# http://qrank.wbsrv.net/
# http://itpro.nikkeibp.co.jp/atcl/news/17/122202911/
# https://engineering.linecorp.com/ja/blog/detail/234
# https://japan.cnet.com/article/35112393/
# https://littleapps.jp/qiita-notifications-crx/
# http://d.hatena.ne.jp/keyword/Qiita
# https://qiitadon.com/
# https://gist.github.com/azu/78c3c9ec42204f3be1fd73123a8588d0
# https://www.weblio.jp/content/Qiita
# https://www.wantedly.com/mid_career/japan/all/qiita
# https://forest.watch.impress.co.jp/docs/news/1094992.html
# https://codezine.jp/article/detail/9759
# https://licensecounter.jp/devops-hub/blog/increments/
# http://blog.jnito.com/entry/2017/06/28/054012
# http://qiita-stock.info/
# https://ameblo.jp/minmeeting/entry-12324229817.html
# https://prtimes.jp/topics/keywords/Qiita
# http://www.nowhere.co.jp/blog/archives/20170511-081142.html
# https://www.slideshare.net/takoratta/qiita-increments
# https://www.npmjs.com/package/qiita
# http://ydkk.hateblo.jp/entry/2017/12/14/235727
# https://marketplace.visualstudio.com/items?itemName=Increments.qiita
# https://robotstart.info/tag/qiita
# https://www.showcase-gig.com/tag/qiita/
# https://codeiq.jp/magazine/2016/01/36482/
# http://team-work.jp/feature/2662.html
# http://engineering.enish.jp/?p=1371
# https://itpropartners.com/blog/9393/
# http://www.i-tap.co.jp/news/73
# http://shgam.hatenadiary.jp/entry/2016/09/11/022923
# https://yro.srad.jp/story/17/05/12/067229/
# http://post.tetsuji.jp/2014/03/use-qiita-and-blog/
# https://type.jp/et/log/article/moimeshi_008
# https://www.rancher.co.jp/qiita/
# https://anond.hatelabo.jp/20150127003906
# https://increments.connpass.com/event/59681/
# http://qiitahackathon03.peatix.com/
# https://mastportal.info/?post_type=mastodon&s=Qiita
# http://logmi.jp/156251
# https://speakerdeck.com/kyuns/qiita-team
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7669b1eaefe9> in <module>()
#       9 #def main():
#      10 #    google_search("qiita")
# ---> 11 google_search("qiita")
#
# <ipython-input-2-7669b1eaefe9> in google_search(query, limit)
#       3
#       4 def google_search(query, limit=10):
# ----> 5     for url in search(query, lang="jp", num=limit):
#       6         print(url)
#       7
#
# ~/anaconda3/lib/python3.6/site-packages/google/__init__.py in search(query, tld, lang, tbs, safe, num, start, stop, pause, only_standard, extra_params, tpe, user_agent)
#     299
#     300         # Sleep between requests.
# --> 301         time.sleep(pause)
#     302
#     303         # Request the Google Search results page.
#
# KeyboardInterrupt:

# %% [markdown]
# 試しに、下記URLに書いてあるコードをコピペしてみた。
#
# https://qiita.com/msrks/items/ed18a2653bc177a24cca
#
# それだけで、何か表示された！！Warningがいくつか出ているのは気にしない。

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

fig = plt.figure(figsize=(8,4))
m = Basemap(projection='merc',
                 resolution='h',
                 llcrnrlon=131,
                 llcrnrlat=33,
                 urcrnrlon=141,
                 urcrnrlat=38)

m.drawcoastlines(color='lightgray')
m.drawcountries(color='lightgray')
m.fillcontinents(color='white', lake_color='#eeeeee');
m.drawmapboundary(fill_color='#eeeeee')
#m.drawparallels(np.arange(31.0, 38.1, 1.0), labels = [1,0,0,0], fontsize=12)
#m.drawmeridians(np.arange(132.0, 140.1, 2.0), labels = [0,0,0,1], fontsize=12)

sumoto_lon = 134.7687
sumoto_lat = 34.3755
hiratsuka_lon = 139.3581
hiratsuka_lat = 35.3587

x1,y1 = m(sumoto_lon, sumoto_lat)
x2,y2 = m(hiratsuka_lon, hiratsuka_lat)
m.plot(x1, y1, 'm.', markersize=10)
m.plot(x2, y2, 'm.', markersize=10)
plt.text(x1 + 10000, y1 + 10000, u"sumoto")
plt.text(x2 + 10000, y2 + 10000, u"hiratsuka")

plt.show()
fig.savefig('map.png')
# Out:
# /Users/kurokawamakoto/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /Users/kurokawamakoto/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1698: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /Users/kurokawamakoto/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/kurokawamakoto/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
